# %% [markdown]
# ## 2. Reducible and Irreducible Errors
# ---
# ![image.png](attachment:image.png)
# 오차항은 random variable로 평균이 0이고 분산이 Var(ε)인 정규분포를 따름.
# ![image-2.png](attachment:image-2.png)
# - 머신러닝 알고리즘은 reducible error를 최소로 하는 것을 목표로 함. irreducible error는 알지 못하는 오차로 조절할 수 없음.
